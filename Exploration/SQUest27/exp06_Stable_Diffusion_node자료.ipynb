# %% [markdown]
# # 수식 없이도 이해할 수 있는 ChatGPT와 Stable Diffusion

# %% [markdown]
# ## Stable Diffusion 모델을 사용하여 이미지를 생성

# %% [markdown]
# ### ChatGPT와 Stable Diffusion 차이점 비교

# %% [markdown]
# #### 1. 생성형 AI(Generative AI)의 시대
# * ChatGPT 사용해 보기

# %% [markdown]
# * ChatGPT : OpenAI가 2022년 말에 발표한 대화형 언어모델
# * 프롬프트(prompt)를 입력하면 결과를 알려준다.

# %% [markdown]
# #### 2. Stable Diffusion 사용해 보기

# %% [markdown]
# * Stability AI에서 오픈소스로 모델을 배포
# * 문장을 쓰면 이미지를 생성해주는 모델
# * 영어로 원하는 문장을 입력
# * https://stablediffusionweb.com/#demo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 3. ChatGPT와 Stable Diffusion은 어떻게 발전되어 왔을까요?

# %% [markdown]
# * Attention Mechanism이 처음 소개된 논문: Neural Machine Translation by Jointly Learning to Align and Translate
# * Self-Attention 논문: Attention is All you need
# * GPT3 논문: Language Models are Few-Shot Learners
# * ImageGPT
#   - OpenAI의 ImageGPT 소개
#   - 논문: Generative Pretraining from Pixels
# * DALL-E
#   - OpenAI의 DALL-E 소개
#   - 논문: Zero-Shot Text-to-Image Generation
# * DALL-E 2
#   - OpenAI의 DALL-E 2 소개
#   - 논문: Hierarchical Text-Conditional Image Generation with CLIP Latents
# * Diffusion 모델 논문: Denoising diffusion probabilistic models (https://arxiv.org/abs/2006.11239)
# * Stable Diffusion 논문: High-Resolution Image Synthesis with Latent Diffusion Models (https://arxiv.org/abs/2112.10752)
# * OpenAI의 ChatGPT 소개 (https://openai.com/index/chatgpt/)
#  - ChatGPT는 GPT3 기반으로 만들어진 모델이라 논문이 없습니다.
# * RLHF 관련 논문: Training language models to follow instructions with human feedback (https://arxiv.org/abs/2203.02155)

# %% [markdown]
# #### 4. 생성형 AI가 바꿀 세상의 모습은?
#
# 1. AI에 대한 지식을 심화시키세요
# 실용적인 응용 프로그램에 집중 : 응용 프로그램 소프트웨어 개발자로서 AI를 소프트웨어 솔루션에 어떻게 통합할 수 있는지 이해하는 것을 우선시합니다.
# AI의 핵심 개념을 알아보세요 . 머신 러닝(ML), 자연어 처리(NLP), 컴퓨터 비전 등 빠르게 발전하는 분야에 대한 이해도를 높여보세요.
# AI 프레임워크로 실험 : TensorFlow, PyTorch, scikit-learn과 같은 프레임워크에 익숙해지세요. 이러한 프레임워크는 AI 모델을 구현하고 이를 애플리케이션에 통합하는 데 도움이 됩니다.
# 2. 소프트웨어 개발에 대한 AI의 영향 이해
# 자동화된 개발 도구 : GitHub Copilot과 같은 AI 기반 도구에 대해 알아보세요. 이 도구는 코드 생성을 지원합니다. 이러한 도구는 개발 기술을 보완할 수 있습니다.
# AI 강화 개발 관행 : AI가 소프트웨어의 디버깅, 테스트, 성능 최적화 등의 영역을 어떻게 개선할 수 있는지 이해합니다.
# 3. AI 인접 분야 전문화
# 경험 활용 : 자신이 일했거나 익숙한 산업에서 AI 솔루션을 탐색하세요. 도메인 지식과 AI 전문 지식을 결합하면 매우 가치가 있습니다.
# MLOps 살펴보기 : 소프트웨어 분야 전문가라면 자연스럽게 익혀야 할, 프로덕션 환경에서 AI 모델을 배포하고 유지 관리하는 방법에 대해 알아보세요.
# 4. 이전 가능한 기술 개발
# 데이터 리터러시 : Pandas, NumPy, Matplotlib과 같은 도구를 사용하여 데이터 조작, 정리, 시각화에 익숙해지세요.
# 클라우드 AI 서비스 : AWS, Google Cloud, Azure와 같은 클라우드 플랫폼에 대해 알아보세요. 이러한 플랫폼은 모든 것을 처음부터 구축하지 않고도 AI를 배포할 수 있는 도구를 제공합니다.
# 5. AI 커뮤니티와 교류
# AI 커뮤니티에 가입하세요 . Reddit의 ML이나 AI subreddit, GitHub 프로젝트, Kaggle 대회 등의 포럼에 참여하세요.
# 동료와 네트워크를 구축하세요 . AI를 배우거나 적용하고 있는 다른 사람들과 교류하기 위해 미팅, 웨비나, 컨퍼런스에 참석하세요.
# 6. AI 트렌드를 앞서가세요
# 지속적인 학습 : AI 블로그, 강좌(예: Coursera, Udemy), 뉴스레터(예: Import AI, The Batch)와 같은 리소스를 팔로우하세요.
# 윤리 및 규정 : AI 윤리, 거버넌스, 사회적 영향에 대한 정보를 얻어 프로젝트를 미래의 규범과 규정에 맞춰 조정하세요.
# 7. 전략적으로 자신을 위치시키세요
# AI 기반 역할로 전환 : AI 소프트웨어 엔지니어나 통합 전문가 등 소프트웨어 개발과 AI를 결합한 역할을 찾아보세요.
# 포트폴리오 개발 : 진화하는 기술을 보여주기 위해 AI 강화 프로젝트(예: 예측 분석, NLP 기능 또는 추천 시스템이 있는 애플리케이션)로 구성된 포트폴리오를 구축하세요.
# 8. 성장 마인드셋을 채택하세요
# 기술은 빠르게 발전하지만 개발자로서의 경험은 강력한 기반입니다. 변화를 받아들이고 지속적인 개선에 집중하세요.

# %% [markdown]
# #### 5. ChatGPT를 사용하여 이미지 프롬프트 만들기

# %% [markdown]
# * 프롬프트 엔지니어링(Prompt Engineering)
# * 이미지를 생성하는 프롬프트를 위주로 프롬프트를 작성하는 법을 배워보기
# * 먼저 기본적인 내용을 배우고, ChatGPT 확장 프로그램을 이용하여 ChatGPT에게 이미지 생성 프롬프트를 만들어 달라고 해보겠습니다.

# %% [markdown]
# * Stable Diffusion 프롬프트 엔지니어링 : 그림이나 사진에서 사용하는 기법이나 기술을 사용

# %% [markdown]
# * 기본 속성 입력
#   - 사진/그림 등
#   - 주제: 사람/동물/풍경/사물 등
#   - 빛: 부드럽게/네온 사인/자연광 등
#   - 주변 환경: 야외/실내/우주/수중 등
#   - 색: 파스텔톤/어둡게/강렬하게 등
#   - 시점: 앞/뒤/옆/위 등
#   - 스타일: 3D/지브리풍/영화 등
# * 하이퍼파라미터
#   - 해상도: 기본값 512 x 512
#   - CFG(Classifier Free Guidance) : 기본값은 7
#   - Step count: 디노이징(denoising, 노이즈를 제거해주는 기법) 스텝의 수 -> 기본값인 50을 사용
#   - seed: 기본값은 random
#   - sampler : 초보자들은 DDIM을 사용

# %% [markdown]
# * ChatGPT에게 이미지 생성 프롬프트를 만들어 달라고 하기
#  - ChatGPT에게 Stable Diffusion 사용을 위한 이미지 생성 프롬프트를 요청
#   - AIPRM for ChatGPT 설치 및 계정 연동하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 6.Stable Diffusion 모델로 이미지 생성하기

# %% [markdown]
# * Stable Diffusion 모델을 이용하여 이미지를 생성
# * 허깅페이스(Hugging Face)를 이용
# * 허깅페이스에서 제공하는 Stable Diffusion 모델 중 Diffusers를 사용
# * Diffusers는 이미지, 오디오, 3D 분자 구조를 생성하는 모델로,
#   파이프라인(Autoencoder, Conditional Unet, CLIP text encoder 등), 스케쥴러(속도와 결과물의 품질 조정), 사전학습된 모델로 구성

# %% [markdown]
# * 모델 준비하기
# * 먼저 Diffusers를 설치

# %%
# Diffusers를 설치
# !pip install --upgrade -qq git+https://github.com/huggingface/diffusers.git transformers accelerate

# %% [markdown]
# * Text-to-Image Generation
#   - Stable Diffusion의 가장 기본적인 기능은 텍스트를 입력하면 이미지를 생성

# %%
import torch 
from diffusers import DiffusionPipeline, DPMSolverMultistepScheduler

device = "cuda"

# 파이프라인 불러오기
repo_id = "stabilityai/stable-diffusion-2-base"
pipe = DiffusionPipeline.from_pretrained(repo_id, torch_dtype=torch.float16)

pipe.scheduler = DPMSolverMultistepScheduler.from_config(pipe.scheduler.config)
pipe = pipe.to(device)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /opt/conda/lib/python3.9/site-packages/diffusers/utils/import_utils.py in _get_module(self, module_name)
#     852         try:
# --> 853             return importlib.import_module("." + module_name, self.__name__)
#     854         except Exception as e:
#
# /opt/conda/lib/python3.9/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# /opt/conda/lib/python3.9/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /opt/conda/lib/python3.9/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /opt/conda/lib/python3.9/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /opt/conda/lib/python3.9/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ...

# %% [markdown]
# * 하나의 이미지 생성하기
